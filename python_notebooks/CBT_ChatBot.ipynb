# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle

import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
# Out:
# [nltk_data] Downloading package punkt to /home/pamripose/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /home/pamripose/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /home/pamripose/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 2023-04-17 20:59:25.215695: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-17 20:59:25.255091: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-04-17 20:59:25.256299: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-17 20:59:25.828182: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('intents.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:

        # take each word and tokenize it
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        # adding documents
        documents.append((w, intent['tag']))

        # adding classes to our class list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

print (len(documents), "documents")

print (len(classes), "classes", classes)

print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 69 documents
# 18 classes ['academic', 'adverse_drug', 'blood_pressure', 'blood_pressure_search', 'cultural', 'goodbye', 'greeting', 'hospital_search', 'how_you_feel', 'negative_core_beliefs', 'nfeel', 'options', 'pfeel', 'pharmacy_search', 'postive_core_beliefs', 'religious', 'thanks', 'why_you_feel']
# 116 unique lemmatized words ["'s", ',', 'a', 'academic', 'adverse', 'all', 'always', 'anxious', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'confident', 'could', 'crush', 'cultural', 'culture', 'data', 'day', 'depressed', 'detail', 'do', 'dont', 'drug', 'enough', 'entry', 'find', 'for', 'give', 'god', 'good', 'goodbye', 'happen', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'job', 'later', 'learning', 'life', 'like', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'make', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'no', 'not', 'of', 'offered', 'open', 'patient', 'people', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'religion', 'result', 'roomate', 'search', 'searching', 'see', 'show', 'study', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'them', 'there', 'thing', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'when', 'which', 'with', 'worthless', 'worthy', 'yes', 'you']

# %%
# initializing training data
training = []
output_empty = [0] * len(classes)
for doc in documents:
    # initializing bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created
# /tmp/ipykernel_203005/74795701.py:22: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %%
# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(lr=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)

print("model created")
# Out:
# 2023-04-17 20:59:27.508744: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-04-17 20:59:27.509387: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1956] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Epoch 1/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.9284 - accuracy: 0.0290
# Epoch 2/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.8113 - accuracy: 0.1449
# Epoch 3/200
# 14/14 [==============================] - 0s 1ms/step - loss: 2.7662 - accuracy: 0.1594
# Epoch 4/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.6793 - accuracy: 0.2029
# Epoch 5/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.6226 - accuracy: 0.1884
# Epoch 6/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.5534 - accuracy: 0.2609
# Epoch 7/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.4162 - accuracy: 0.3043
# Epoch 8/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.3142 - accuracy: 0.3623
# Epoch 9/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.0277 - accuracy: 0.4203
# Epoch 10/200
# 14/14 [==============================] - 0s 2ms/step - loss: 2.0194 - accuracy: 0.4348
# Epoch 11/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.8638 - accuracy: 0.4928
# Epoch 12/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.7095 - accuracy: 0.5362
# Epoch 13/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.7394 - accuracy: 0.4928
# Epoch 14/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.5668 - accuracy: 0.5072
# Epoch 15/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.4787 - accuracy: 0.5652
# Epoch 16/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.4552 - accuracy: 0.6232
# Epoch 17/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.2996 - accuracy: 0.6522
# Epoch 18/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3020 - accuracy: 0.6232
# Epoch 19/200
# 14/14 [==============================] - 0s 2ms/step - loss: 1.3038 - accuracy: 0.6087
# Epoch 20/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.1331 - accuracy: 0.7101
# Epoch 21/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.2242 - accuracy: 0.5797
# Epoch 22/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.2175 - accuracy: 0.6377
# Epoch 23/200
# 14/14 [==============================] - 0s 1ms/step - loss: 1.0132 - accuracy: 0.7536
# Epoch 24/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.9076 - accuracy: 0.6957
# Epoch 25/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.9163 - accuracy: 0.7391
# Epoch 26/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.9428 - accuracy: 0.7681
# Epoch 27/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.9028 - accuracy: 0.7971
# Epoch 28/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.8097 - accuracy: 0.7826
# Epoch 29/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.7963 - accuracy: 0.8116
# Epoch 30/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.7168 - accuracy: 0.8116
# Epoch 31/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.7926 - accuracy: 0.7536
# Epoch 32/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5741 - accuracy: 0.9275
# Epoch 33/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5899 - accuracy: 0.8696
# Epoch 34/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6465 - accuracy: 0.8696
# Epoch 35/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.5945 - accuracy: 0.8406
# Epoch 36/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.6031 - accuracy: 0.8406
# Epoch 37/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5019 - accuracy: 0.8696
# Epoch 38/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.6082 - accuracy: 0.7826
# Epoch 39/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4791 - accuracy: 0.8986
# Epoch 40/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5584 - accuracy: 0.8696
# Epoch 41/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5197 - accuracy: 0.8551
# Epoch 42/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3674 - accuracy: 0.9130
# Epoch 43/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.5053 - accuracy: 0.8696
# Epoch 44/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4079 - accuracy: 0.9130
# Epoch 45/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4484 - accuracy: 0.8986
# Epoch 46/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.4024 - accuracy: 0.8986
# Epoch 47/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3647 - accuracy: 0.8986
# Epoch 48/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.4079 - accuracy: 0.8841
# Epoch 49/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3263 - accuracy: 0.9420
# Epoch 50/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3759 - accuracy: 0.8696
# Epoch 51/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2690 - accuracy: 0.9710
# Epoch 52/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3161 - accuracy: 0.9565
# Epoch 53/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1793 - accuracy: 0.9710
# Epoch 54/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2965 - accuracy: 0.9420
# Epoch 55/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3095 - accuracy: 0.8986
# Epoch 56/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2020 - accuracy: 0.9565
# Epoch 57/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3191 - accuracy: 0.9275
# Epoch 58/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2428 - accuracy: 0.9420
# Epoch 59/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2980 - accuracy: 0.9275
# Epoch 60/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.3468 - accuracy: 0.9130
# Epoch 61/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.3012 - accuracy: 0.9420
# Epoch 62/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2263 - accuracy: 0.9710
# Epoch 63/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2919 - accuracy: 0.9130
# Epoch 64/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2237 - accuracy: 0.9565
# Epoch 65/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2990 - accuracy: 0.9130
# Epoch 66/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2558 - accuracy: 0.9420
# Epoch 67/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2747 - accuracy: 0.8986
# Epoch 68/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2959 - accuracy: 0.9275
# Epoch 69/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2406 - accuracy: 0.9420
# Epoch 70/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2077 - accuracy: 0.9420
# Epoch 71/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2145 - accuracy: 0.9275
# Epoch 72/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2380 - accuracy: 0.9420
# Epoch 73/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1941 - accuracy: 0.9420
# Epoch 74/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2047 - accuracy: 0.9710
# Epoch 75/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1643 - accuracy: 0.9855
# Epoch 76/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1899 - accuracy: 0.9565
# Epoch 77/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1442 - accuracy: 0.9855
# Epoch 78/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2086 - accuracy: 0.9565
# Epoch 79/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0736 - accuracy: 1.0000
# Epoch 80/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1999 - accuracy: 0.9420
# Epoch 81/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1643 - accuracy: 0.9855
# Epoch 82/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2188 - accuracy: 0.9565
# Epoch 83/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2043 - accuracy: 0.9565
# Epoch 84/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1232 - accuracy: 0.9710
# Epoch 85/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1388 - accuracy: 0.9710
# Epoch 86/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1447 - accuracy: 0.9565
# Epoch 87/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1022 - accuracy: 0.9710
# Epoch 88/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1587 - accuracy: 0.9710
# Epoch 89/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1313 - accuracy: 0.9565
# Epoch 90/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0664 - accuracy: 1.0000
# Epoch 91/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2526 - accuracy: 0.9275
# Epoch 92/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1552 - accuracy: 0.9565
# Epoch 93/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1153 - accuracy: 0.9710
# Epoch 94/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0911 - accuracy: 0.9855
# Epoch 95/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1541 - accuracy: 0.9710
# Epoch 96/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1352 - accuracy: 0.9565
# Epoch 97/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0760 - accuracy: 0.9855
# Epoch 98/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1773 - accuracy: 0.9855
# Epoch 99/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1292 - accuracy: 0.9710
# Epoch 100/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1207 - accuracy: 0.9710
# Epoch 101/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1134 - accuracy: 0.9855
# Epoch 102/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0740 - accuracy: 0.9855
# Epoch 103/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.2274 - accuracy: 0.9420
# Epoch 104/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0599 - accuracy: 1.0000
# Epoch 105/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1247 - accuracy: 0.9710
# Epoch 106/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0940 - accuracy: 0.9710
# Epoch 107/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1829 - accuracy: 0.9420
# Epoch 108/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1486 - accuracy: 0.9565
# Epoch 109/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1043 - accuracy: 0.9855
# Epoch 110/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1427 - accuracy: 0.9565
# Epoch 111/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1851 - accuracy: 0.9565
# Epoch 112/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0925 - accuracy: 0.9565
# Epoch 113/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1184 - accuracy: 0.9855
# Epoch 114/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1309 - accuracy: 0.9710
# Epoch 115/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1217 - accuracy: 0.9420
# Epoch 116/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0924 - accuracy: 0.9855
# Epoch 117/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1241 - accuracy: 0.9710
# Epoch 118/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0607 - accuracy: 1.0000
# Epoch 119/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1756 - accuracy: 0.9420
# Epoch 120/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0959 - accuracy: 0.9710
# Epoch 121/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1536 - accuracy: 0.9565
# Epoch 122/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0982 - accuracy: 0.9565
# Epoch 123/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1049 - accuracy: 0.9855
# Epoch 124/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1133 - accuracy: 0.9565
# Epoch 125/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0876 - accuracy: 0.9710
# Epoch 126/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.2322 - accuracy: 0.9420
# Epoch 127/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1146 - accuracy: 0.9710
# Epoch 128/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0680 - accuracy: 0.9855
# Epoch 129/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1080 - accuracy: 0.9710
# Epoch 130/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0604 - accuracy: 1.0000
# Epoch 131/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1142 - accuracy: 0.9565
# Epoch 132/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0855 - accuracy: 0.9710
# Epoch 133/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0443 - accuracy: 1.0000
# Epoch 134/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1813 - accuracy: 0.9420
# Epoch 135/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0776 - accuracy: 0.9855
# Epoch 136/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1169 - accuracy: 0.9565
# Epoch 137/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0608 - accuracy: 0.9855
# Epoch 138/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.9855
# Epoch 139/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0599 - accuracy: 1.0000
# Epoch 140/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0438 - accuracy: 0.9855
# Epoch 141/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0609 - accuracy: 0.9855
# Epoch 142/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0513 - accuracy: 1.0000
# Epoch 143/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0633 - accuracy: 0.9855
# Epoch 144/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0525 - accuracy: 1.0000
# Epoch 145/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0583 - accuracy: 0.9855
# Epoch 146/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0438 - accuracy: 1.0000
# Epoch 147/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 148/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0676 - accuracy: 0.9710
# Epoch 149/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0448 - accuracy: 0.9710
# Epoch 150/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0289 - accuracy: 1.0000
# Epoch 151/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1060 - accuracy: 0.9710
# Epoch 152/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1050 - accuracy: 0.9710
# Epoch 153/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0728 - accuracy: 0.9710
# Epoch 154/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0437 - accuracy: 0.9855
# Epoch 155/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0511 - accuracy: 0.9855
# Epoch 156/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0844 - accuracy: 0.9855
# Epoch 157/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0755 - accuracy: 0.9855
# Epoch 158/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0573 - accuracy: 1.0000
# Epoch 159/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0619 - accuracy: 1.0000
# Epoch 160/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0435 - accuracy: 0.9855
# Epoch 161/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0591 - accuracy: 0.9855
# Epoch 162/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0843 - accuracy: 0.9710
# Epoch 163/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0788 - accuracy: 0.9710
# Epoch 164/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0216 - accuracy: 0.9855
# Epoch 165/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1017 - accuracy: 0.9565
# Epoch 166/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.1006 - accuracy: 0.9855
# Epoch 167/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0553 - accuracy: 1.0000
# Epoch 168/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0700 - accuracy: 0.9855
# Epoch 169/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 170/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0822 - accuracy: 0.9855
# Epoch 171/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9710
# Epoch 172/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0705 - accuracy: 1.0000
# Epoch 173/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0390 - accuracy: 0.9855
# Epoch 174/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 175/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0928 - accuracy: 0.9710
# Epoch 176/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0108 - accuracy: 1.0000
# Epoch 177/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0820 - accuracy: 0.9710
# Epoch 178/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0326 - accuracy: 1.0000
# Epoch 179/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1153 - accuracy: 0.9710
# Epoch 180/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0415 - accuracy: 0.9855
# Epoch 181/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0660 - accuracy: 0.9855
# Epoch 182/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0659 - accuracy: 0.9565
# Epoch 183/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0844 - accuracy: 0.9855
# Epoch 184/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 0.9855
# Epoch 185/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0462 - accuracy: 0.9855
# Epoch 186/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.1465 - accuracy: 0.9420
# Epoch 187/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 188/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0616 - accuracy: 0.9710
# Epoch 189/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0539 - accuracy: 1.0000
# Epoch 190/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 191/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0283 - accuracy: 0.9855
# Epoch 192/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0384 - accuracy: 0.9855
# Epoch 193/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0691 - accuracy: 0.9855
# Epoch 194/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0819 - accuracy: 0.9855
# Epoch 195/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0343 - accuracy: 0.9855
# Epoch 196/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 197/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9710
# Epoch 198/200
# 14/14 [==============================] - 0s 2ms/step - loss: 0.0451 - accuracy: 1.0000
# Epoch 199/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0376 - accuracy: 1.0000
# Epoch 200/200
# 14/14 [==============================] - 0s 1ms/step - loss: 0.0264 - accuracy: 0.9855
# model created

# %%
from keras.models import load_model
model = load_model('chatbot_model.h5')
import json
import random
intents = json.loads(open('intents.json').read())
words = pickle.load(open('words.pkl','rb'))
classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

# return bag of words array: 0 or 1 for each word in the bag that exists in the sentence

def bow(sentence, words, show_details=True):
    # tokenize the pattern
    sentence_words = clean_up_sentence(sentence)
    # bag of words - matrix of N words, vocabulary matrix
    bag = [0]*len(words)
    for s in sentence_words:
        for i,w in enumerate(words):
            if w == s:
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    # filter out predictions below a threshold
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]
    # sort by strength of probability
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(msg):
    ints = predict_class(msg, model)
    res = getResponse(ints, intents)
    return res

# %%
#Creating GUI with tkinter
import tkinter
from tkinter import *


def send():
    msg = EntryBox.get("1.0",'end-1c').strip()
    EntryBox.delete("0.0",END)

    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12 ))

        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')

        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)


base = Tk()
base.title("SAM")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)

ChatLog.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(base, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b",fg='#ffffff',
                    command= send )

#Create the box to enter message
EntryBox = Text(base, bd=0, bg="white",width="29", height="5", font="Arial")
#EntryBox.bind("<Return>", send)


#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatLog.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

base.mainloop()
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 25ms/step
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/pamripose/anaconda3/lib/python3.10/tkinter/__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "/tmp/ipykernel_203005/4195933570.py", line 15, in send
#     res = chatbot_response(msg)
#   File "/tmp/ipykernel_203005/1370899457.py", line 46, in chatbot_response
#     res = getResponse(ints, intents)
#   File "/tmp/ipykernel_203005/1370899457.py", line 36, in getResponse
#     tag = ints[0]['intent']
# IndexError: list index out of range
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 15ms/step
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/home/pamripose/anaconda3/lib/python3.10/tkinter/__init__.py", line 1921, in __call__
#     return self.func(*args)
#   File "/tmp/ipykernel_203005/4195933570.py", line 15, in send
#     res = chatbot_response(msg)
#   File "/tmp/ipykernel_203005/1370899457.py", line 46, in chatbot_response
#     res = getResponse(ints, intents)
#   File "/tmp/ipykernel_203005/1370899457.py", line 36, in getResponse
#     tag = ints[0]['intent']
# IndexError: list index out of range
# 1/1 [==============================] - 0s 31ms/step
